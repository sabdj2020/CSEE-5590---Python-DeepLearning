# %%
# import libraries
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
# Loading data and plotting the digit
(train_images,train_labels),(test_images, test_labels) = mnist.load_data()
#display the first image in the training data
plt.imshow(train_images[0,:,:],cmap='gray')
plt.title('Ground Truth : {}'.format(train_labels[0]))
# plt.show()
# Out:
# Text(0.5, 1.0, 'Ground Truth : 5')

# %%
# Processing the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)
#convert data to float and scale values between 0 and 1
train_data.astype('float')
test_data.astype('float')
#scale data
train_data //=255
test_data //=255
#change the labels frominteger to one-hot encoding
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# %%
#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=20, verbose=1,
          validation_data=(test_data, test_labels_one_hot))
# Out:
# Epoch 1/20
# 235/235 [==============================] - 5s 20ms/step - loss: 1.7770 - accuracy: 0.3780 - val_loss: 1.6691 - val_accuracy: 0.3983
# Epoch 2/20
# 235/235 [==============================] - 5s 20ms/step - loss: 1.6084 - accuracy: 0.4218 - val_loss: 1.6517 - val_accuracy: 0.4042
# Epoch 3/20
# 235/235 [==============================] - 5s 20ms/step - loss: 1.5698 - accuracy: 0.4311 - val_loss: 1.6348 - val_accuracy: 0.4174
# Epoch 4/20
# 235/235 [==============================] - 5s 20ms/step - loss: 1.5424 - accuracy: 0.4413 - val_loss: 1.6093 - val_accuracy: 0.4264
# Epoch 5/20
# 235/235 [==============================] - 4s 19ms/step - loss: 1.5222 - accuracy: 0.4458 - val_loss: 1.6092 - val_accuracy: 0.4217
# Epoch 6/20
# 235/235 [==============================] - 4s 19ms/step - loss: 1.5048 - accuracy: 0.4510 - val_loss: 1.6178 - val_accuracy: 0.4239
# Epoch 7/20
# 235/235 [==============================] - 4s 19ms/step - loss: 1.4894 - accuracy: 0.4587 - val_loss: 1.6203 - val_accuracy: 0.4264
# Epoch 8/20
# 235/235 [==============================] - 4s 18ms/step - loss: 1.4761 - accuracy: 0.4609 - val_loss: 1.6368 - val_accuracy: 0.4229
# Epoch 9/20
# 235/235 [==============================] - 4s 18ms/step - loss: 1.4646 - accuracy: 0.4636 - val_loss: 1.6318 - val_accuracy: 0.4249
# Epoch 10/20
# 235/235 [==============================] - 5s 19ms/step - loss: 1.4533 - accuracy: 0.4680 - val_loss: 1.6536 - val_accuracy: 0.4160
# Epoch 11/20
# 235/235 [==============================] - 4s 18ms/step - loss: 1.4419 - accuracy: 0.4730 - val_loss: 1.6666 - val_accuracy: 0.4178
# Epoch 12/20
# 235/235 [==============================] - 5s 22ms/step - loss: 1.4334 - accuracy: 0.4756 - val_loss: 1.6746 - val_accuracy: 0.4249
# Epoch 13/20
# 235/235 [==============================] - 5s 22ms/step - loss: 1.4238 - accuracy: 0.4776 - val_loss: 1.6822 - val_accuracy: 0.4280
# Epoch 14/20
# 235/235 [==============================] - 5s 20ms/step - loss: 1.4176 - accuracy: 0.4799 - val_loss: 1.6919 - val_accuracy: 0.4206
# Epoch 15/20
# 235/235 [==============================] - 4s 18ms/step - loss: 1.4086 - accuracy: 0.4842 - val_loss: 1.7088 - val_accuracy: 0.4233
# Epoch 16/20
# 235/235 [==============================] - 5s 21ms/step - loss: 1.4033 - accuracy: 0.4852 - val_loss: 1.7016 - val_accuracy: 0.4287
# Epoch 17/20
# 235/235 [==============================] - 5s 23ms/step - loss: 1.3955 - accuracy: 0.4875 - val_loss: 1.7222 - val_accuracy: 0.4212
# Epoch 18/20
# 235/235 [==============================] - 5s 23ms/step - loss: 1.3915 - accuracy: 0.4893 - val_loss: 1.7334 - val_accuracy: 0.4268
# Epoch 19/20
# 235/235 [==============================] - 5s 21ms/step - loss: 1.3906 - accuracy: 0.4908 - val_loss: 1.7318 - val_accuracy: 0.4230
# Epoch 20/20
# 235/235 [==============================] - 5s 21ms/step - loss: 1.3821 - accuracy: 0.4926 - val_loss: 1.7447 - val_accuracy: 0.4244

# %%
# Evaluation
predict = model.predict_classes(test_data[[0], :])
print(predict1)
[test_loss, test_acc] = model.evaluate(test_data, test_labels_one_hot)

print("Evaluation result on Test Data : Loss = {}, accuracy = {}".format(test_loss, test_acc))
print("*********************************")
print(history.history.keys())
# Out:
# [7]
# 313/313 [==============================] - 1s 2ms/step - loss: 1.7447 - accuracy: 0.4244
# Evaluation result on Test Data : Loss = 1.7447069883346558, accuracy = 0.4244000017642975
# *********************************
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# question 1
# using history object for plotting loss

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss model')
plt.ylabel('loss')
plt.xlabel('num of epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# using history object for plotting accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('accuracy model')
plt.ylabel('accuracy')
plt.xlabel('numer of epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
